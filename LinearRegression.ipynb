# %%
import pandas as pd
data = pd.read_csv("/var/home/rafo/vscode02/PR/Advertising.csv",usecols=[1,2,3,4])
df= data.copy()
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(df , kind="reg")
# Out:
# /var/home/rafo/.local/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(x = "TV", y= "sales", kind = "reg", data = df)

# %%
import statsmodels.api as sm

# %%
x = df["TV"]
x=sm.add_constant(x)
x[0:5]
# Out:
#    const     TV
# 0    1.0  230.1
# 1    1.0   44.5
# 2    1.0   17.2
# 3    1.0  151.5
# 4    1.0  180.8

# %%
y = df["sales"]
lm = sm.OLS(y,x)
model = lm.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Tue, 18 Jul 2023   Prob (F-statistic):           1.47e-42
# Time:                        21:15:49   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
model.params
# Out:
# const    7.032594
# TV       0.047537
# dtype: float64

# %%
model.resid
# Out:
# 0      4.129225
# 1      1.252026
# 2      1.449776
# 3      4.265605
# 4     -2.727218
#          ...
# 195   -1.248493
# 196   -1.810545
# 197   -2.646579
# 198    4.986015
# 199   -4.665848
# Length: 200, dtype: float64

# %%
df["Error"] = model.resid

# %%
import numpy as np
np.sqrt((df["Error"]**2).mean())
# Out:
# 3.2423221486546883
