# %%
from datetime import datetime
import pandas as pd

# %%
df = pd.read_csv("/data/RetailTurnover.csv",parse_dates=["Year"])

# %%
df
# Out:
#          Year Quarter  Turnover
# 0  1982-01-01      Q3   13423.2
# 1  1982-01-01      Q4   13128.8
# 2  1983-01-01      Q1   15398.8
# 3  1983-01-01      Q2   12964.2
# 4  1983-01-01      Q3   13133.5
# 5  1983-01-01      Q4   13271.7
# 6  1984-01-01      Q1   15596.3
# 7  1984-01-01      Q2   13018.0
# 8  1984-01-01      Q3   13409.3
# 9  1984-01-01      Q4   13304.2
# 10 1985-01-01      Q1   15873.9
# 11 1985-01-01      Q2   13366.5
# 12 1985-01-01      Q3   13998.6
# 13 1985-01-01      Q4   14045.1
# 14 1986-01-01      Q1   16650.3
# 15 1986-01-01      Q2   13598.4
# 16 1986-01-01      Q3   14183.2
# 17 1986-01-01      Q4   14128.5
# 18 1987-01-01      Q1   16380.7
# 19 1987-01-01      Q2   13512.8
# 20 1987-01-01      Q3   14022.1
# 21 1987-01-01      Q4   14231.8
# 22 1988-01-01      Q1   16737.0
# 23 1988-01-01      Q2   14004.5
# 24 1988-01-01      Q3   14165.5
# 25 1988-01-01      Q4   14203.9
# 26 1989-01-01      Q1   16895.1
# 27 1989-01-01      Q2   14248.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      39 non-null     datetime64[ns]
#  1   Quarter   39 non-null     object
#  2   Turnover  39 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 1.0+ KB

# %%
data_range = pd.date_range(start = "1982-01-01",end = "1990-01-01", freq="Q")

# %%
data_range
# Out:
# DatetimeIndex(['1982-03-31', '1982-06-30', '1982-09-30', '1982-12-31',
#                '1983-03-31', '1983-06-30', '1983-09-30', '1983-12-31',
#                '1984-03-31', '1984-06-30', '1984-09-30', '1984-12-31',
#                '1985-03-31', '1985-06-30', '1985-09-30', '1985-12-31',
#                '1986-03-31', '1986-06-30', '1986-09-30', '1986-12-31',
#                '1987-03-31', '1987-06-30', '1987-09-30', '1987-12-31',
#                '1988-03-31', '1988-06-30', '1988-09-30', '1988-12-31',
#                '1989-03-31', '1989-06-30', '1989-09-30', '1989-12-31'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %%
quarter_df = pd.pivot_table(df,values= "Turnover",columns= "Quarter",index="Year")

# %%
quarter_df
# Out:
# Quarter          Q1       Q2       Q3       Q4
# Year
# 1982-01-01      NaN      NaN  13423.2  13128.8
# 1983-01-01  15398.8  12964.2  13133.5  13271.7
# 1984-01-01  15596.3  13018.0  13409.3  13304.2
# 1985-01-01  15873.9  13366.5  13998.6  14045.1
# 1986-01-01  16650.3  13598.4  14183.2  14128.5
# 1987-01-01  16380.7  13512.8  14022.1  14231.8
# 1988-01-01  16737.0  14004.5  14165.5  14203.9
# 1989-01-01  16895.1  14248.2  14719.5  14855.8
# 1990-01-01  17361.6  14585.2  14873.5  14798.4
# 1991-01-01  17115.2  14284.9  14558.8  14914.3
# 1992-01-01  17342.3      NaN      NaN      NaN

# %%
quarter_df.plot(colormap = "rainbow")
# Out:
# <Axes: xlabel='Year'>

# %%
import matplotlib.pyplot as plt
quarter_df.plot(kind = 'box',colormap="plasma")
plt.grid(True)
